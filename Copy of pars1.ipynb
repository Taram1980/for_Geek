# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json

# %%
username = "Taram1980"
url = "https://api.github.com/users/{}/repos".format(username)
repo_list = requests.get(url)

# %%
with open('repo_list.json', 'w') as f:
    json.dump(repo_list.json(), f)

# %%
for i in repo_list.json():
  print(i['name'])
# Out:
# Customer_Clustering
# finance_ML
# for_Geek
# OECD-Project

# %% [markdown]
# 2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
token = 'sRmkWEtYSN8XGEDX3myY7g'
companys_id = '320193,1418091'

# %%
next = requests.get('https://api.usfundamentals.com/v1/companies/xbrl?companies={}&format=json&token={}'.format(companys_id, token))
print(next.status_code)
# Out:
# 200

# %%
with open('usfund.json', 'w') as f:
  json.dump(next.json(), f)

# %%
for i in next.json():
  print(i['company_id'])
# Out:
# 320193
# 1418091
